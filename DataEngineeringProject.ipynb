# %%
import pandas as pd
dbrands=pd.read_csv(r"C:\Users\City World\OneDrive\Documents\Data Engineering\brands.csv")
dcategories=pd.read_csv(r"C:\Users\City World\OneDrive\Documents\Data Engineering\categories.csv")
dcustomers=pd.read_csv(r"C:\Users\City World\OneDrive\Documents\Data Engineering\customers.csv")
dorder_items=pd.read_csv(r"C:\Users\City World\OneDrive\Documents\Data Engineering\order_items.csv")
dorders=pd.read_csv(r"C:\Users\City World\OneDrive\Documents\Data Engineering\orders.csv")
dproducts=pd.read_csv(r"C:\Users\City World\OneDrive\Documents\Data Engineering\products.csv")
dstaffs=pd.read_csv(r"C:\Users\City World\OneDrive\Documents\Data Engineering\staffs.csv")
dstocks=pd.read_csv(r"C:\Users\City World\OneDrive\Documents\Data Engineering\stocks.csv")
dstores=pd.read_csv(r"C:\Users\City World\OneDrive\Documents\Data Engineering\stores.csv")

# %%
print(
f"the number of rows in brands is {dbrands.shape[0]}\n"
,f"the number of columns in brands is {dbrands.shape[1]}\n"
,f"the number of rows in categories is {dcategories.shape[0]}\n"
,f"the number of columns in categories is {dcategories.shape[1]}\n"
,f"the number of rows in customers is {dcustomers.shape[0]}\n"
,f"the number of columns in customers is {dcustomers.shape[1]}\n"
,f"the number of rows in order_items is {dorder_items.shape[0]}\n"
,f"the number of columns in order_items is {dorder_items.shape[1]}\n"
,f"the number of rows in orders is {dorders.shape[0]}\n"
,f"the number of columns in orders is {dorders.shape[1]}\n"
,f"the number of rows in products is {dproducts.shape[0]}\n"
,f"the number of columns in products is {dproducts.shape[1]}\n"
,f"the number of rows in staffs is {dstaffs.shape[0]}\n"
,f"the number of columns in staffs is {dstaffs.shape[1]}\n"
,f"the number of rows in stocks is {dstocks.shape[0]}\n"
,f"the number of columns in stocks is {dstocks.shape[1]}\n"
,f"the number of rows in stores is {dstores.shape[0]}\n"
,f"the number of columns in stores is {dstores.shape[1]}\n"
)
# Out:
# the number of rows in brands is 9
#  the number of columns in brands is 2
#  the number of rows in categories is 7
#  the number of columns in categories is 2
#  the number of rows in customers is 1445
#  the number of columns in customers is 9
#  the number of rows in order_items is 4764
#  the number of columns in order_items is 6
#  the number of rows in orders is 1615
#  the number of columns in orders is 8
#  the number of rows in products is 334
#  the number of columns in products is 6
#  the number of rows in staffs is 10
#  the number of columns in staffs is 8
#  the number of rows in stocks is 939
#  the number of columns in stocks is 3
#  the number of rows in stores is 3
#  the number of columns in stores is 8

# %%
print ("The count of ROWS and COLUMNS in each dataset is:")
datasets_information=[]
datasets= pd.DataFrame(
    {
        "dataset_name":["brands","categories","customers","order_items","orders","products","staffs","stocks","stores"]
        ,"rows": [dbrands.shape[0],dcategories.shape[0],dcustomers.shape[0],dorder_items.shape[0],dorders.shape[0],dproducts.shape[0],dstaffs.shape[0],dstocks.shape[0],dstores.shape[0]
                 ]
        ,"columns": [dbrands.shape[1],dcategories.shape[1],dcustomers.shape[1],dorder_items.shape[1],dorders.shape[1],dproducts.shape[1],dstaffs.shape[1],dstocks.shape[1],dstores.shape[1]
                 ]
    }
)
print (datasets)
print("datasets names are:\n brands\n,categories\n,customers\n,order_items\n,orders\n,products\n,staffs\n,stocks\n,stores\n")
# Out:
# The count of ROWS and COLUMNS in each dataset is:
#   dataset_name  rows  columns
# 0       brands     9        2
# 1   categories     7        2
# 2    customers  1445        9
# 3  order_items  4764        6
# 4       orders  1615        8
# 5     products   334        6
# 6       staffs    10        8
# 7       stocks   939        3
# 8       stores     3        8
# datasets names are:
#  brands
# ,categories
# ,customers
# ,order_items
# ,orders
# ,products
# ,staffs
# ,stocks
# ,stores

# %%
# all columns' names are standardized already but here is the solution 
dbrands.columns=dbrands.columns.str.lower().str.replace(" ", "_")
dcategories.columns=dcategories.columns.str.lower().str.replace(" ", "_")
dcustomers.columns=dcustomers.columns.str.lower().str.replace(" ", "_")
dorder_items.columns=dorder_items.columns.str.lower().str.replace(" ", "_")
dorders.columns=dorders.columns.str.lower().str.replace(" ", "_")
dproducts.columns=dproducts.columns.str.lower().str.replace(" ", "_")
dstaffs.columns=dstaffs.columns.str.lower().str.replace(" ", "_")
dstocks.columns=dstocks.columns.str.lower().str.replace(" ", "_")
dstores.columns=dstores.columns.str.lower().str.replace(" ", "_")

# %%
pd.set_option('display.max.rows', 5000)

# %%
#brands, categories dataset is already cleaned
#customers needs cleaning

# %%
# to remove charachters: df["columns"].str.strip("the chars")
#removing all strange characters in a number column: df["columns"].str.replace('[^a-zA-Z0-9]')
# replace('[^0-9]','') anything that is not a number from 0 to 9 will be replaced by none aka removed
# lambda function:
# df["column"].apply(lambda x: x[0:3]+'-'+ x[3:6]+'-'+ x[6:])

# %%
dcustomers["phone"]=dcustomers["phone"].fillna("unknown")
dcustomers.isnull().sum()
dcustomers=dcustomers.drop_duplicates()
#no nulls and duplicates in customers

# %%
dorder_items
dorder_items.isnull().sum()
# no nulls in order items
# handeling duplicates
dorder_items=dorder_items.drop_duplicates()

# %%
dorders=pd.read_csv(r"C:\Users\City World\OneDrive\Documents\Data Engineering\orders.csv")
dorders["shipped_date"]=dorders["shipped_date"].fillna("unshipped yet")
unshipped_orders=dorders[dorders["shipped_date"]== "unshipped yet"]
# removed null values and return the rows of unasigned shipped date if needed

# %%
#products duplicates handled even there were none
dproducts=dproducts.drop_duplicates()
null=dproducts.isnull().sum()
print(null)
#no null values found
# Out:
# product_id      0
# product_name    0
# brand_id        0
# category_id     0
# model_year      0
# list_price      0
# dtype: int64

# %%
dstaffs.isnull().sum()
#one null value in each of last name, email, store id, manager id, and 2 in phone
dstaffs["last_name"]=dstaffs["last_name"].fillna("")
dstaffs["email"]=dstaffs["email"].fillna("user's email not found")
dstaffs["phone"]=dstaffs["phone"].fillna("unknown")
dstaffs["store_id"]=dstaffs["store_id"].fillna("no store id found")
dstaffs["manager_id"]=dstaffs["manager_id"].fillna("no manager assigned")
dstaffs=dstaffs.drop_duplicates()
#null values and duplicates handeled

# %%
dstocks.isnull().sum()
# no null values found
dstocks=dstocks.drop_duplicates()
#duplicates handled if there was any

# %%
dstores.isnull().sum()
# 1 null found in email and 1 in zip code
# will assign a zip code for the state in the row and handle the other null in the email
# we can insert and email for the store with no email value but it may not be a standard thing
# if email is standardized for each store in a certain formate we can assign email as following:
dstores.loc[0,"email"]="santacruz@bikes.shop"
dstores.loc[0,"zip_code"]=95060

# %%
#setting datatypes
#brands
dbrands["brand_id"]=dbrands["brand_id"].astype(int)
dbrands["brand_name"]=dbrands["brand_name"].astype(object)

#categories
dcategories["category_id"]=dcategories["category_id"].astype(int)
dcategories["category_name"]=dcategories["category_name"].astype(object)

#customers
dcustomers["customer_id"]=dcustomers["customer_id"].astype(int)

#order_items
#for col in ["order_id","item_id","product_id"]:
    #dorder_items[col]=dorder_items[col].astype(int)
#didn't work so there non integer values init
dorder_items["order_id"]=dorder_items["order_id"].astype(int)
dorder_items["product_id"]=dorder_items["product_id"].astype(int)
# only items id has non integer char in it and it is a part of the id 

#orders
dorders["order_id"]=dorders["order_id"].astype(int)
dorders["customer_id"]=dorders["customer_id"].astype(int)
dorders["store_id"]=dorders["store_id"].astype(int)
dorders["staff_id"]=dorders["staff_id"].astype(int)
#dates datatype handled but later I handled the null values by string so the dates are accurate but the datatype is string to handle null values

#products
dproducts["product_id"]=dproducts["product_id"].astype(int)
dproducts["brand_id"]=dproducts["brand_id"].astype(int)
dproducts["category_id"]=dproducts["category_id"].astype(int)
dproducts["list_price"]=dproducts["list_price"].astype(float)

#staffs
dstaffs["store_id"]=dstaffs["store_id"].replace("no store id found","0")
dstaffs["manager_id"]=dstaffs["manager_id"].replace("no manager assigned","0")
dstaffs["store_id"]=dstaffs["store_id"].astype(float).astype(int)
dstaffs["manager_id"]=dstaffs["manager_id"].astype(float).astype(int)
#datatypes in dstaffs handled

#stocks
ids_in_stocks=["store_id","product_id"]
dstocks[ids_in_stocks]=dstocks[ids_in_stocks].astype(int)
dstocks["quantity"]=dstocks["quantity"].astype(int)
#datatypes in stocks handled

#stores
dstores["store_id"]=dstores["store_id"].astype(int)
#datatypes in stores handled

# %%
#order items
#dorder_items.loc[dorder_items["list_price"]<0] # no negative values in price found


#products
#dproducts.loc[dproducts["list_price"]<0], returns no negative values in list_price in products

#stocks
#dstocks.loc[dstocks["quantity"]<0], returns no negative values in quantity in stocks

#now all the format issues and outliers in the datasets are set
#no duplicates found too

# %%
#Merge products with brands and categories

# %%
dproducts
# Out:
#      product_id                                       product_name  brand_id  \
# 0             1                                    Trek 820 - 2016         9
# 1             2                 Ritchey Timberwolf Frameset - 2016         5
# 2             3                    Surly Wednesday Frameset - 2016         8
# 3             4                           Trek Fuel EX 8 29 - 2016         9
# 4             5                       Heller Shagamaw Frame - 2016         3
# 5             6              Surly Ice Cream Truck Frameset - 2016         8
# 6             7                           Trek Slash 8 27.5 - 2016         9
# 7             8              Trek Remedy 29 Carbon Frameset - 2016         9
# 8             9                               Trek Conduit+ - 2016         9
# 9            10                             Surly Straggler - 2016         8
# 10           11                        Surly Straggler 650b - 2016         8
# ...

# %%
dbrands
# Out:
#    brand_id    brand_name
# 0         1       Electra
# 1         2          Haro
# 2         3        Heller
# 3         4   Pure Cycles
# 4         5       Ritchey
# 5         6       Strider
# 6         7  Sun Bicycles
# 7         8         Surly
# 8         9          Trek

# %%
brands_products=dproducts.merge(dbrands, on="brand_id", how= "outer")

# %%
dcategories
# Out:
#    category_id        category_name
# 0            1    Children Bicycles
# 1            2     Comfort Bicycles
# 2            3    Cruisers Bicycles
# 3            4  Cyclocross Bicycles
# 4            5       Electric Bikes
# 5            6       Mountain Bikes
# 6            7           Road Bikes

# %%
#products merged with categories
products_categories=dproducts.merge(dcategories, on= "category_id", how="outer")

# %%
#merge the brands_products table with categories on categories_id
#all three are merged together
br_pr_categ= brands_products.merge(dcategories, on = "category_id", how= "outer")

# %%
#products and brands merged to --> brands_products
#products and categories merged to --> products_categories
#products, brands and categories are merged to --> br_pr_categ

# %%
#total price in order items : total_price = quantity * list_price 
dorder_items["total_price"]=dorder_items["quantity"]*dorder_items["list_price"]

# %%
#Calculate order total amount (sum of all items grouped by order_id)
order_items_count=(
    dorder_items.groupby("order_id", as_index=False)["quantity"]
    .sum()
    .rename(columns={"quantity":"total_items"})
)
order_items_count
# Out:
#       order_id  total_items
# 0            1            8
# 1            2            3
# 2            3            2
# 3            4            2
# 4            5            4
# 5            6            8
# 6            7            4
# 7            8            3
# 8            9            2
# 9           10            1
# 10          11            5
# 11          12            3
# 12          13            7
# 13          14            1
# 14          15            7
# 15          16            5
# 16          17            5
# 17          18            8
# 18          19            3
# 19          20            3
# 20          21            3
# 21          22            3
# 22          23            5
# 23          24            4
# 24          25            7
# 25          26            5
# 26          27            5
# 27          28            6
# 28          29            8
# 29          30            6
# 30          31            4
# 31          32            6
# ...

# %%
#Create a full_name column for customers  
dcustomers["full_name"]=dcustomers["first_name"]+" "+dcustomers["last_name"]

# %%
#Clean and standardize customer phone numbers:
dcustomers["phone"]=dcustomers["phone"].str.replace('[^a-z0-9]','',regex= True)

# %%
#changeing the names of the cleaned dataframes
dbrands_cleaned=dbrands.copy()
dcategories_cleaned=dcategories.copy()
dcustomers_cleaned=dcustomers.copy()
dorder_items_cleaned=dorder_items.copy()
dorders_cleaned=dorders.copy()
dproducts_cleaned=dproducts.copy()
dstaffs_cleaned=dstaffs.copy()
dstocks_cleaned=dstocks.copy()
dstores_cleaned=dstores.copy()

# %%
#exporting it to csv files
dbrands_cleaned.to_csv("dbrands_cleaned.csv") #done
dcategories_cleaned.to_csv("dcategories_cleaned.csv") #done
dcustomers_cleaned.to_csv("dcustomers_cleaned.csv")#done
dorder_items_cleaned.to_csv("dorder_items_cleaned.csv") #done
dorders_cleaned.to_csv("dorders_cleaned.csv") #done
dproducts_cleaned.to_csv("dproducts_cleaned.csv") #done
dstaffs_cleaned.to_csv("dstaffs_cleaned.csv") #done
dstocks_cleaned.to_csv("dstocks_cleaned.csv")
dstores_cleaned.to_csv("dstores_cleaned.csv")#done

# %%
dorders_cleaned["order_status"]=dorders["order_status"].astype(int)
dstores_cleaned["phone"]=dstores_cleaned["phone"].str.replace('[^a-z0-9]','',regex= True)
dstores_cleaned["zip_code"]=dstores_cleaned["zip_code"].astype(int)
